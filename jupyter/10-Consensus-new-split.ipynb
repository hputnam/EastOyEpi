# %% [markdown]
# Sam split then updated VCF
# https://github.com/RobertsLab/resources/issues/528

# %%
cd /Volumes/Serine/wd/19-01-08
# Out:
# /Volumes/Serine/wd/19-01-08

# %% [markdown]
# # DOWNLOAD

# %%
# !wget -r -np -k http://gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/
# Out:
# --2019-01-08 14:23:43--  http://gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/
# Resolving gannet.fish.washington.edu (gannet.fish.washington.edu)... 128.95.149.52
# Connecting to gannet.fish.washington.edu (gannet.fish.washington.edu)|128.95.149.52|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/index.html’
#
# gannet.fish.washing     [ <=>                ]  25.37K  --.-KB/s    in 0s
#
# 2019-01-08 14:23:43 (66.2 MB/s) - ‘gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/index.html’ saved [25975]
#
# Loading robots.txt; please ignore errors.
# --2019-01-08 14:23:43--  http://gannet.fish.washington.edu/robots.txt
# Reusing existing connection to gannet.fish.washington.edu:80.
# HTTP request sent, awaiting response... 404 Not Found
# 2019-01-08 14:23:43 ERROR 404: Not Found.
#
# ...

# %% [markdown]
# # INDEX

# %%
# %%bash
# find /Volumes/Serine/wd/19-01-08/gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/*vcf.gz \
# | xargs basename -s .vcf.gz | xargs -I{} /Applications/bioinfo/bcftools-1.3.1/bcftools index \
# /Volumes/Serine/wd/19-01-08/gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/{}.vcf.gz
# Out:
# [E::hts_open_format] fail to open file '/Volumes/Serine/wd/19-01-08/gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.vcf.gz'
# Failed to read /Volumes/Serine/wd/19-01-08/gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.vcf.gz

# %% [markdown]
# # CONSENSUS FROM VCF

# %%
# %%bash
# find /Volumes/Serine/wd/19-01-08/gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/*vcf.gz \
# | xargs basename -s .vcf.gz | xargs -I{} /Applications/bioinfo/bcftools-1.3.1/bcftools consensus \
# -f /Volumes/Serine/wd/18-03-15/genome/GCF_002022765.2_C_virginica-3.0_genomic.fa \
# /Volumes/Serine/wd/19-01-08/gannet.fish.washington.edu/Atumefaciens/20190103_Cvirginica_vcf_splitting/{}.vcf.gz \
# -o /Volumes/Serine/wd/19-01-08/{}.fa

# %%
# !ls /Volumes/Serine/wd/19-01-08/*fa | head
# Out:
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_1.fa
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_2.fa
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_3.fa
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_4.fa
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_5.fa
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_6.fa
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CL_1.fa
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CL_2.fa
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CL_3.fa
# /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CL_4.fa

# %% [markdown]
# # getfasta from sample specfic genomes

# %%
# %%bash
# find /Volumes/Serine/wd/19-01-08/*.fa \
# | xargs basename -s .fa | xargs -I{} /Applications/bioinfo/bedtools2/bin/bedtools getfasta \
# -fi /Volumes/Serine/wd/19-01-08/{}.fa \
# -bed /Users/sr320/git-repos/nb-2018/C_virginica/data/ref_C_virginica-3.0_Gnomon_gene.gff3 \
# -fo /Volumes/Serine/wd/19-01-08/{}_GENE.fa
# Out:
# index file /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_1.fa.fai not found, generating...
# index file /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_2.fa.fai not found, generating...
# index file /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_3.fa.fai not found, generating...
# index file /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_4.fa.fai not found, generating...
# index file /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_5.fa.fai not found, generating...
# index file /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CLP_6.fa.fai not found, generating...
# index file /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.CL_1.fa.fai not found, generating...
# ...

# %%
# !ls -fo /Volumes/Serine/wd/19-01-08/*_GENE.fa | wc -l
# Out:
#       91

# %%
# !fgrep ">" /Volumes/Serine/wd/19-01-08/Combined.SNP.TRSdp5g95FnDNAmaf05.sorted.ANACfill.UMFS_3_GENE.fa | wc -l
# Out:
#    38929
